# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv(r"D:\intern\archive (7)\creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.shape
# Out:
# (284807, 31)

# %%
from sklearn.model_selection import train_test_split

# %%
x=data[['Time','Amount']]
y=data['Class']

# %%
x
# Out:
#             Time  Amount
# 0            0.0  149.62
# 1            0.0    2.69
# 2            1.0  378.66
# 3            1.0  123.50
# 4            2.0   69.99
# ...          ...     ...
# 284802  172786.0    0.77
# 284803  172787.0   24.79
# 284804  172788.0   67.88
# 284805  172788.0   10.00
# 284806  172792.0  217.00
#
# [284807 rows x 2 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#             Time  Amount
# 83225    59741.0   38.42
# 52800    45648.0   61.20
# 21293    31579.0  110.95
# 133600   80455.0   10.00
# 38225    39302.0   22.00
# ...          ...     ...
# 119879   75618.0    1.98
# 259178  159000.0   89.23
# 131932   79795.0    3.94
# 146867   87931.0    1.00
# 121958   76381.0  113.00
#
# [213605 rows x 2 columns]

# %%
y_train
# Out:
# 83225     0
# 52800     0
# 21293     0
# 133600    0
# 38225     0
#          ..
# 119879    0
# 259178    0
# 131932    0
# 146867    0
# 121958    0
# Name: Class, Length: 213605, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model= LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#           Time         V1         V2        V3        V4        V5        V6  \
# 0            0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0   1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1  -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1  -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2  -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...        ...        ...        ...       ...       ...       ...       ...
# 284802  124588 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  124589  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804  124590   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  124590  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  124591  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %%
X_test
# Out:
#             Time  Amount
# 43428    41505.0  364.19
# 49906    44261.0  520.12
# 29474    35484.0   31.00
# 276481  167123.0    1.50
# 278846  168473.0    0.89
# ...          ...     ...
# 234953  148184.0    0.99
# 235147  148270.0   17.41
# 199459  132978.0   89.80
# 172357  121067.0   20.00
# 110731   71950.0   15.80
#
# [71202 rows x 2 columns]

# %%
y_pred = model.predict(X_test)

# %%
accuracy = model.score(X_test, y_test)

print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.9984129659279234

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
input=(41.0,364.19)
input1=np.asarray(input)
int2=input1.reshape(1,-1)

# %%
int2
# Out:
# array([[ 41.  , 364.19]])

# %%
pred=model.predict(int2)
# Out:
# C:\Users\lavan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(pred)
# Out:
# [0]

# %%
if pred == 0:
    print("The transaction is not fraudulent.",pred)
else:
    print("The transaction is fraudulent.",pred)
# Out:
# The transaction is not fraudulent. [0]
