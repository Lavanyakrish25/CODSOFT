# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"D:\intern\archive (7)\tested.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Embarked
# ...

# %%
data1=data.drop('Name',axis=1)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch  \
# 0            892         0       3    1  34.50000      0      0
# 1            893         1       3    0  47.00000      1      0
# 2            894         0       2    1  62.00000      0      0
# 3            895         0       3    1  27.00000      0      0
# 4            896         1       3    0  22.00000      1      1
# ..           ...       ...     ...  ...       ...    ...    ...
# 413         1305         0       3    1  30.27259      0      0
# 414         1306         1       1    0  39.00000      0      0
# 415         1307         0       3    1  38.50000      0      0
# 416         1308         0       3    1  30.27259      0      0
# 417         1309         0       3    1  30.27259      1      1
#
#                  Ticket      Fare  Embarked
# 0                330911    7.8292         1
# 1                363272    7.0000         2
# 2                240276    9.6875         1
# ...

# %%
x=data1.drop('Survived',axis=1)

# %%
y=data1['Survived']

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

data1['Age'] = imputer.fit_transform(data1[['Age']])
data1['Age'] = imputer.transform(data1[['Age']])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data1['Sex'] = label_encoder.fit_transform(data1['Sex'])
data1['Sex'] = label_encoder.transform(data1['Sex'])

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

data1['Embarked'] = imputer.fit_transform(data1[['Embarked']])
data1['Embarked'] = imputer.transform(data1[['Embarked']])

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

data1['Fare'] = imputer.fit_transform(data1[['Fare']])
data1['Fare'] = imputer.transform(data1[['Fare']])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()


data1['Embarked'] = label_encoder.fit_transform(data1['Embarked'])
data1['Embarked'] = label_encoder.transform(data1['Embarked'])

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

data1['Ticket'] = label_encoder.fit_transform(data1['Ticket'])

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0          892         0       3    1  34.5      0      0     152   7.8292
# 1          893         1       3    0  47.0      1      0     221   7.0000
# 2          894         0       2    1  62.0      0      0      73   9.6875
# 3          895         0       3    1  27.0      0      0     147   8.6625
# 4          896         1       3    0  22.0      1      1     138  12.2875
#
#    Embarked
# 0         1
# 1         2
# 2         1
# 3         2
# 4         2

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

train = scaler.fit_transform(data1[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']])
test = scaler.transform(data1[['Pclass','Sex', 'Age', 'SibSp', 'Parch', 'Fare']])

# %%
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x=data1.drop('Survived',axis=1)
y=data1['Survived']

# %%
x
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch  Ticket      Fare  \
# 0            892       3    1  34.50000      0      0     152    7.8292
# 1            893       3    0  47.00000      1      0     221    7.0000
# 2            894       2    1  62.00000      0      0      73    9.6875
# 3            895       3    1  27.00000      0      0     147    8.6625
# 4            896       3    0  22.00000      1      1     138   12.2875
# ..           ...     ...  ...       ...    ...    ...     ...       ...
# 413         1305       3    1  30.27259      0      0     267    8.0500
# 414         1306       1    0  39.00000      0      0     324  108.9000
# 415         1307       3    1  38.50000      0      0     346    7.2500
# 416         1308       3    1  30.27259      0      0     220    8.0500
# 417         1309       3    1  30.27259      1      1     105   22.3583
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8)

# %%
x_train
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch  Ticket      Fare  \
# 249         1141       3    0  30.27259      1      0     102   14.4542
# 236         1128       1    1  64.00000      1      0       2   75.2500
# 105          997       3    1  28.00000      0      0     278   22.5250
# 179         1071       1    0  64.00000      0      2     322   83.1583
# 25           917       3    1  50.00000      1      0     273   14.5000
# ..           ...     ...  ...       ...    ...    ...     ...       ...
# 108         1000       3    1  30.27259      0      0     163    8.7125
# 36           928       3    0  30.27259      0      0     166    8.0500
# 316         1208       1    1  57.00000      1      0     307  146.5208
# 261         1153       3    1  21.00000      0      0     217    7.8542
# 175         1067       2    0  15.00000      0      2     134   39.0000
#
#      Embarked
# 249         0
# 236         0
# 105         2
# 179         0
# 25          2
# ...

# %%
x_test
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch  Ticket     Fare  \
# 323         1215       1    1  33.00000      0      0      19  26.5500
# 135         1027       3    1  24.00000      0      0     216   7.8542
# 237         1129       3    1  20.00000      0      0     112   7.2250
# 228         1120       3    1  40.50000      0      0     293  15.1000
# 401         1293       2    1  38.00000      1      0     128  21.0000
# ..           ...     ...  ...       ...    ...    ...     ...      ...
# 362         1254       2    0  31.00000      0      0     295  21.0000
# 294         1186       3    1  36.00000      0      0     173   9.5000
# 223         1115       3    1  21.00000      0      0     211   7.7958
# 132         1024       3    0  30.27259      0      4     256  25.4667
# 325         1217       3    1  23.00000      0      0     349   7.0500
#
#      Embarked
# 323         2
# 135         2
# 237         0
# 228         2
# 401         2
# ..        ...
# ...

# %%
y_train
# Out:
# 249    1
# 236    0
# 105    0
# 179    1
# 25     0
#       ..
# 108    0
# 36     1
# 316    0
# 261    0
# 175    1
# Name: Survived, Length: 83, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\lavan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy = model.score(x_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0

# %%
x.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  Embarked
# 0          892       3    1  34.5      0      0     152   7.8292         1
# 1          893       3    0  47.0      1      0     221   7.0000         2
# 2          894       2    1  62.0      0      0      73   9.6875         1
# 3          895       3    1  27.0      0      0     147   8.6625         2
# 4          896       3    0  22.0      1      1     138  12.2875         2

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Survived, dtype: int64

# %%
input=(893,3,0,47.00000,1,0,221,7.0000,2)
input1=np.asarray(input)
int2=input1.reshape(1,-1)

# %%
int2
# Out:
# array([[893.,   3.,   0.,  47.,   1.,   0., 221.,   7.,   2.]])

# %%
pred=model.predict(int2)
print(pred)
# Out:
# [1]
# C:\Users\lavan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if pred == 0:
    print("The person survived",pred)
else:
    print("The person not survived",pred)
# Out:
# The person not survived [1]
